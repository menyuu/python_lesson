# %%
import numpy as np
import pandas as pd

# %%
# 一次元
s = pd.Series([1, 2, np.nan])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
s[0]
# Out:
# 1.0

# %%
s.sum()
# Out:
# 3.0

# %%
# 二次元
df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df.dtypes
# Out:
# A    int64
# B    int64
# dtype: object

# %%
# 6 x 4 のランダムな値
df = pd.DataFrame(np.random.randn(6, 4))
df
# Out:
#           0         1         2         3
# 0 -2.154644  1.186934 -1.021715  1.477142
# 1 -0.329277  0.725475 -0.701764 -0.660422
# 2 -0.555419  0.398304 -1.170250  1.948584
# 3 -0.300914 -0.237531  0.762758  0.067884
# 4  1.179006 -0.444400 -1.083847  0.057104
# 5  0.130221  1.057053 -1.685407 -0.812048

# %%
# インデックス部分に日付を入れることができる
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20220101', periods=6))

# %%
df
# Out:
#                    0         1         2         3
# 2022-01-01  0.965022 -0.782042 -1.562792  0.217369
# 2022-01-02  0.774866 -0.046050 -0.999756  0.803190
# 2022-01-03  0.002557 -1.925166 -1.544157  0.196664
# 2022-01-04 -0.930639  0.161214  0.499294  0.921899
# 2022-01-05 -0.453628  0.259610 -0.490956 -0.876658
# 2022-01-06  0.002772 -1.956910  0.808614  1.451701

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20220101', periods=6), columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505
# 2022-01-03 -0.980117  0.614178 -1.194256 -0.473033
# 2022-01-04  1.545466 -0.756314 -0.678088  1.074305
# 2022-01-05  0.883891 -0.980443  0.992800 -0.394950
# 2022-01-06  0.707297 -0.924857  0.324163 -0.833199

# %%
# 上のデータの呼び出し
# 引数は上から何個目までの呼び出しをするか
df.head(2)
# Out:
#                    A         B         C         D
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505

# %%
# 下のデータの呼び出し
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-01-04  1.545466 -0.756314 -0.678088  1.074305
# 2022-01-05  0.883891 -0.980443  0.992800 -0.394950
# 2022-01-06  0.707297 -0.924857  0.324163 -0.833199

# %%
df.index
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 1.09895636,  0.50208646, -1.04226027,  0.07162276],
#        [-0.08177983, -1.57583122, -1.31222937, -0.44850516],
#        [-0.98011672,  0.61417777, -1.1942564 , -0.47303333],
#        [ 1.54546597, -0.75631416, -0.67808785,  1.07430514],
#        [ 0.88389077, -0.98044252,  0.9928    , -0.39495034],
#        [ 0.70729725, -0.92485731,  0.32416315, -0.83319899]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.528952 -0.520197 -0.484978 -0.167293
# std    0.912828  0.880632  0.935287  0.673270
# min   -0.980117 -1.575831 -1.312229 -0.833199
# 25%    0.115489 -0.966546 -1.156257 -0.466901
# 50%    0.795594 -0.840586 -0.860174 -0.421728
# 75%    1.045190  0.187486  0.073600 -0.045021
# max    1.545466  0.614178  0.992800  1.074305

# %%
# データの反転
df.T
# Out:
#    2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  2022-01-06
# A    1.098956   -0.081780   -0.980117    1.545466    0.883891    0.707297
# B    0.502086   -1.575831    0.614178   -0.756314   -0.980443   -0.924857
# C   -1.042260   -1.312229   -1.194256   -0.678088    0.992800    0.324163
# D    0.071623   -0.448505   -0.473033    1.074305   -0.394950   -0.833199

# %%
# B の昇順で表示している
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505
# 2022-01-05  0.883891 -0.980443  0.992800 -0.394950
# 2022-01-06  0.707297 -0.924857  0.324163 -0.833199
# 2022-01-04  1.545466 -0.756314 -0.678088  1.074305
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623
# 2022-01-03 -0.980117  0.614178 -1.194256 -0.473033

# %%
# スライスで 0番目からの3つを表示
df[0:3]
# Out:
#                    A         B         C         D
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505
# 2022-01-03 -0.980117  0.614178 -1.194256 -0.473033

# %%
df['20220102':'20220104']
# Out:
#                    A         B         C         D
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505
# 2022-01-03 -0.980117  0.614178 -1.194256 -0.473033
# 2022-01-04  1.545466 -0.756314 -0.678088  1.074305

# %%
# 20220101 の横に並んだデータを取り出す
df.loc['20220101']
# Out:
# A    1.098956
# B    0.502086
# C   -1.042260
# D    0.071623
# Name: 2022-01-01 00:00:00, dtype: float64

# %%
df.loc['20220102', ['A', 'B']]
# Out:
# A   -0.081780
# B   -1.575831
# Name: 2022-01-02 00:00:00, dtype: float64

# %%
df.loc['20220102':'20220104', ['A', 'B']]
# Out:
#                    A         B
# 2022-01-02 -0.081780 -1.575831
# 2022-01-03 -0.980117  0.614178
# 2022-01-04  1.545466 -0.756314

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2022-01-01  1.098956  0.502086
# 2022-01-02 -0.081780 -1.575831
# 2022-01-03 -0.980117  0.614178
# 2022-01-04  1.545466 -0.756314
# 2022-01-05  0.883891 -0.980443
# 2022-01-06  0.707297 -0.924857

# %%
# 0 の 0 にあるデータ(20220101, A)
# i をつけることによって整数でデータを呼び出すことができる(int)
df.iloc[0, 0]
# Out:
# 1.0989563572031302

# %%
df.iloc[2, 3]
# Out:
# -0.4730333287976815

# %%
# 縦の 0~2番目のデータと横の 0~3番目のデータ
df.iloc[0:2, 0:3]
# Out:
#                    A         B         C
# 2022-01-01  1.098956  0.502086 -1.042260
# 2022-01-02 -0.081780 -1.575831 -1.312229

# %%
# A のうちにある 0よりも大きいデータを呼び出す
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623
# 2022-01-04  1.545466 -0.756314 -0.678088  1.074305
# 2022-01-05  0.883891 -0.980443  0.992800 -0.394950
# 2022-01-06  0.707297 -0.924857  0.324163 -0.833199

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-01-01  1.098956  0.502086       NaN  0.071623
# 2022-01-02       NaN       NaN       NaN       NaN
# 2022-01-03       NaN  0.614178       NaN       NaN
# 2022-01-04  1.545466       NaN       NaN  1.074305
# 2022-01-05  0.883891       NaN  0.992800       NaN
# 2022-01-06  0.707297       NaN  0.324163       NaN

# %%
df
# Out:
#                    A         B         C         D
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505
# 2022-01-03 -0.980117  0.614178 -1.194256 -0.473033
# 2022-01-04  1.545466 -0.756314 -0.678088  1.074305
# 2022-01-05  0.883891 -0.980443  0.992800 -0.394950
# 2022-01-06  0.707297 -0.924857  0.324163 -0.833199

# %%
# コピーしてデータの追加
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623    one
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505    one
# 2022-01-03 -0.980117  0.614178 -1.194256 -0.473033    two
# 2022-01-04  1.545466 -0.756314 -0.678088  1.074305  three
# 2022-01-05  0.883891 -0.980443  0.992800 -0.394950   four
# 2022-01-06  0.707297 -0.924857  0.324163 -0.833199  three

# %%
# df2 にある 'one' や 'four' が含まれているデータ
df2[df2['E'].isin(['one', 'four'])]
# Out:
#                    A         B         C         D     E
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623   one
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505   one
# 2022-01-05  0.883891 -0.980443  0.992800 -0.394950  four

# %%
df
# Out:
#                    A         B         C         D
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505
# 2022-01-03 -0.980117  0.614178 -1.194256 -0.473033
# 2022-01-04  1.545466 -0.756314 -0.678088  1.074305
# 2022-01-05  0.883891 -0.980443  0.992800 -0.394950
# 2022-01-06  0.707297 -0.924857  0.324163 -0.833199

# %%
s = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20220101', periods=6))

# %%
s
# Out:
# 2022-01-01    1
# 2022-01-02    2
# 2022-01-03    3
# 2022-01-04    4
# 2022-01-05    5
# 2022-01-06    6
# Freq: D, dtype: int64

# %%
df['E'] = s

# %%
df
# Out:
#                    A         B         C         D  E
# 2022-01-01  1.098956  0.502086 -1.042260  0.071623  1
# 2022-01-02 -0.081780 -1.575831 -1.312229 -0.448505  2
# 2022-01-03 -0.980117  0.614178 -1.194256 -0.473033  3
# 2022-01-04  1.545466 -0.756314 -0.678088  1.074305  4
# 2022-01-05  0.883891 -0.980443  0.992800 -0.394950  5
# 2022-01-06  0.707297 -0.924857  0.324163 -0.833199  6

# %%
# 値を一行データをずらすことができる
df.shift(1)
# Out:
#                    A         B         C         D    E
# 2022-01-01       NaN       NaN       NaN       NaN  NaN
# 2022-01-02  1.098956  0.502086 -1.042260  0.071623  1.0
# 2022-01-03 -0.081780 -1.575831 -1.312229 -0.448505  2.0
# 2022-01-04 -0.980117  0.614178 -1.194256 -0.473033  3.0
# 2022-01-05  1.545466 -0.756314 -0.678088  1.074305  4.0
# 2022-01-06  0.883891 -0.980443  0.992800 -0.394950  5.0

# %%
df = pd.DataFrame(np.random.randn(2, 2))

# %%
df
# Out:
#           0         1
# 0  0.225227  0.377279
# 1  0.205236  0.155443

# %%
# データをくっつけることができる
pd.concat([df, df])
# Out:
#           0         1
# 0  0.225227  0.377279
# 1  0.205236  0.155443
# 0  0.225227  0.377279
# 1  0.205236  0.155443

# %%
df = pd.DataFrame(np.random.rand(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.558699  0.830106  0.605302  0.628776
# 1  0.974276  0.203647  0.432165  0.059277
# 2  0.041422  0.245126  0.513718  0.173761
# 3  0.243906  0.888911  0.450714  0.119645
# 4  0.083429  0.331614  0.879413  0.097733
# 5  0.848350  0.104232  0.522244  0.121101
# 6  0.925025  0.649225  0.812027  0.980325
# 7  0.618044  0.764951  0.193637  0.224037

# %%
s = df.iloc[0]
s
# Out:
# A    0.558699
# B    0.830106
# C    0.605302
# D    0.628776
# Name: 0, dtype: float64

# %%
# append は現在非推奨？
# append の代わりに concat を使う
# そのまま使うとデータの整合性が取れなくなるので pd.DataFrame([s]) でデータを追加する
df = pd.concat([df, pd.DataFrame([s])])
df
# Out:
#           A         B         C         D
# 0  0.558699  0.830106  0.605302  0.628776
# 1  0.974276  0.203647  0.432165  0.059277
# 2  0.041422  0.245126  0.513718  0.173761
# 3  0.243906  0.888911  0.450714  0.119645
# 4  0.083429  0.331614  0.879413  0.097733
# 5  0.848350  0.104232  0.522244  0.121101
# 6  0.925025  0.649225  0.812027  0.980325
# 7  0.618044  0.764951  0.193637  0.224037
# 0  0.558699  0.830106  0.605302  0.628776

# %%
# そのまま concat すると インデックス番号が順番通りにならないので ignore_index=True をする
df = pd.concat([df, pd.DataFrame([s])], ignore_index=True)
df
# Out:
#           A         B         C         D
# 0  0.558699  0.830106  0.605302  0.628776
# 1  0.974276  0.203647  0.432165  0.059277
# 2  0.041422  0.245126  0.513718  0.173761
# 3  0.243906  0.888911  0.450714  0.119645
# 4  0.083429  0.331614  0.879413  0.097733
# 5  0.848350  0.104232  0.522244  0.121101
# 6  0.925025  0.649225  0.812027  0.980325
# 7  0.618044  0.764951  0.193637  0.224037
# 8  0.558699  0.830106  0.605302  0.628776
# 9  0.558699  0.830106  0.605302  0.628776

# %%
# グルーピング
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar'], 'B': np.random.randn(4)})

# %%
df
# Out:
#      A         B
# 0  foo -1.105524
# 1  bar  0.567248
# 2  foo -0.849216
# 3  bar  0.043105

# %%
# A のデータをグルーピングして合計する
df.groupby('A').sum()
# Out:
#             B
# A
# bar  0.610354
# foo -1.954740

# %%
import pandas_datareader

# %%
# yahoo の API で APPLE の株価を取得し df で返す
df = pandas_datareader.data.DataReader('AAPL', 'yahoo', '2022-01-01')

# %%
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-12-31  179.229996  177.259995  178.089996  177.570007   64062300.0
# 2022-01-03  182.880005  177.710007  177.830002  182.009995  104487900.0
# 2022-01-04  182.940002  179.119995  182.630005  179.699997   99310400.0
# 2022-01-05  180.169998  174.639999  179.610001  174.919998   94537600.0
# 2022-01-06  175.300003  171.639999  172.699997  172.000000   96904000.0
# ...                ...         ...         ...         ...          ...
# 2022-10-28  157.500000  147.820007  148.199997  155.740005  164762400.0
# 2022-10-31  154.240005  151.919998  153.160004  153.339996   97943200.0
# 2022-11-01  155.449997  149.130005  155.080002  150.649994   80379300.0
# 2022-11-02  152.169998  145.000000  148.949997  145.029999   93604600.0
# 2022-11-03  142.800003  138.750000  142.059998  138.880005   97572100.0
#
#              Adj Close
# Date
# 2021-12-31  176.838242
# 2022-01-03  181.259918
# 2022-01-04  178.959457
# 2022-01-05  174.199158
# 2022-01-06  171.291183
# ...                ...
# 2022-10-28  155.740005
# 2022-10-31  153.339996
# 2022-11-01  150.649994
# 2022-11-02  145.029999
# 2022-11-03  138.880005
#
# [213 rows x 6 columns]
